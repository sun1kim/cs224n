# %% [markdown]
# ### 1. Vector representation with high-dimension
# ### 2. Similarity
# [cosine similarity](python.ipynb) - inner product space
# - low complexity, for sparse vectors.
# - two proportional vectors : 1
# - two orthogonal vectors : 0
# - two opposite vectors : -1

# %% [markdown]
# ### Word Embeddings
# ### Analogies
# - king - man + woman = queen
# - no memorizing, but understand the geometric relationships between concepts.

# %% [markdown]
# Q. where does the vector representation come from?
# ### Creating an embedding
# - Feature engineering		  - Trait Matrix (Manual)
# - Psychometrics				  - Big Five / OCEAN
# - AI / LLM (Dense Embeddings) - AI Text Embeddings

# %% [markdown]
# ### Natural Language Model
# - next-word prediction
# 1. input features
# 2. trained language model
# 	- look up embeddings
# 	- calculate prediction
# 	- project to output vocab
# 3. prediction

# %% [markdown]
# N-grams
# tokenization
# pattern based approcahes

# %% [markdown]
# How many words in a sentence?
# - type element of the vocab
# - instance of that type in running text
# - space
# How many words in an utterance?
# **Tokenization**
